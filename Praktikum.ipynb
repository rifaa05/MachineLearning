# %% [markdown]
# <a href="https://colab.research.google.com/github/rifaa05/MachineLearning/blob/main/Praktikum.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **CUPLIKAN**

# %%
import pandas as pd, seaborn as sns
import matplotlib.pyplot as plt

df = sns.load_dataset('iris')
df.info()         # struktur & tipe data
df.isnull().sum() # cek nilai hilang

sns.heatmap(df.corr(numeric_only=True), annot=True)
plt.show()        #matriks korelasi
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# # Langkah 1-Menyiapkan pustaka & memuat data.

# %%
import pandas as pd, numpy as np
import matplotlib.pyplot as plt, seaborn as sns
sns.set_theme(style ='whitegrid')
df = sns.load_dataset('iris')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# # Langkah 2-Mengenali struktur

# %%
print(df.shape)
df.info()
df.describe()
# Out:
# (150, 5)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# ...

# %% [markdown]
# # Langkah 3-Memeriksa kualitas data.

# %%
print(df.isnull().sum())
print(df.duplicated().sum())
print(df['species'].value_counts())
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64
# 1
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %% [markdown]
# # Langkah 4-Distribusi (histogram & box plot).

# %%
df.select_dtypes(include='number').hist(figsize=(9,6), bins=15)
plt.show()
sns.boxplot (data=df.select_dtypes (include='number'))
plt.title('Deteksi Outlier'); plt.show()

# %% [markdown]
# # Langkah 5- Hubungan antar-variabel (scatter & pairplot)

# %%
sns.scatterplot(data=df, x='petal_length', y='petal_width', hue ='species')
plt.show()
sns.pairplot (df, hue='species'); plt.show()

# %% [markdown]
# # Langkah 6-Matriks korelasi(heatmap)

# %%
num = df.select_dtypes (include='number')
sns.heatmap(num.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.show()
